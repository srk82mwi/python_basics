# %%
import python_functions.calculator as calculator

a=int(input("Enter value of a: "))
b=int(input("Enter value of b: "))

print(f"{a} + {b} = {calculator.add(a,b)}")
print(f"{a} - {b} = {calculator.sub(a,b)}")
print(f"{a} * {b} = {calculator.mul(a,b)}")
print(f"{a} / {b} = {round(calculator.div(a,b),2)}")
# Out:
# 5 + 2 = 7
# 5 - 2 = 3
# 5 * 2 = 10
# 5 / 2 = 2.5

# %%
import python_functions.calculator as calculator

a=20
b=10
sum,sub,mul,div = calculator.all_arith(a,b)
print(f"{a} + {b} = {sum}")
print(f"{a} - {b} = {sub}")
print(f"{a} * {b} = {mul}")
print(f"{a} / {b} = {div}")
# Out:
# 20 + 10 = 30
# 20 - 10 = 10
# 20 * 10 = 200
# 20 / 10 = 2.0

# %%
a = 30
b = 10

#ignore return value using _
_,_,mul,_ = calculator.all_arith(a,b) 
print(f"{a} * {b} = {mul}")
# Out:
# 30 * 10 = 300
