# %% [markdown]
# **Class 2**
# - f-strings & Type casting
# - Variables, Data types

# %%
name = "ali"
print(f"Hi {name}, Welcome to python programming")
# Out:
# Hi ali, Welcome to python programming

# %%
print("my name is","shafique","i teach in ggc isakhel", sep="/")
# Out:
# my name is/shafique/i teach in ggc isakhel

# %%
greeting ="Hi , welcome to python programming"
name ="shafiq"
print(greeting,name,sep="*")
# Out:
# Hi , welcome to python programming*shafiq

# %%
a=10
b=20
print(f"{a}+{b}={a+b}")
print(f"{a}-{b}={a-b}")
print(f"{a}*{b}={a*b}")
print(f"{a}/{b}={a/b}")
# Out:
# 10+20=30
# 10-20=-10
# 10*20=200
# 10/20=0.5

# %%
a,b=10,20
print(a,b)
# Out:
# 10 20

# %%
a=b=c=10
print(a,b,c)
# Out:
# 10 10 10

# %% [markdown]
# **Data types**

# %%
num1 = 10
num2 = 23.4
print(f"data type of {num1} is {type(num1)} and {num2} is {type(num2)}")
# Out:
# data type of 10 is <class 'int'> and 23.4 is <class 'float'>

# %%
name ="shafiq"
print("data type of name is",type(name))
# Out:
# data type of name is <class 'str'>

# %% [markdown]
# **Rounding float⭐**
# - using round() method
# - f-string()

# %%
a = 12.3456
print(a)
print(round(a,2))
print(f"{a:.2f}")
# Out:
# 12.3456
# 12.35
# 12.35

# %% [markdown]
# ### **Converting integer / float to string**

# %%
marks = 75 #integer value
print(type(marks))
marks = str(marks)
print(type(marks))
marks = marks +' is a string now'
print(marks)

# print(marks + 4)

marks_av = 64.5
print(type(marks_av))

marks_av = str(marks_av)
print(type(marks_av))
# Out:
# <class 'int'>
# <class 'str'>
# 75 is a string now
# <class 'float'>
# <class 'str'>

# %% [markdown]
# **Math equations**
# - e=mc^2

# %%
m=4 # m variable 
c=5 # c variable
print(f"m={m} c={c} e=mc^2 = {m*c**2}")
# Out:
# m=4 c=5 e=mc^2 = 100

# %% [markdown]
# **Type casting / Type Conversion**

# %%
x=10
print(f"x={x},{type(x)}")
x = float(x)
print(f"x={x},{type(x)}")
x = int(x)
print(f"x={x},{type(x)}")
# Out:
# x=10,<class 'int'>
# x=10.0,<class 'float'>
# x=10,<class 'int'>

# %%
a=23.6
print(a)
b=int(a)
print(b)
# Out:
# 23.6
# 23

# %% [markdown]
# **String to integer**
# - invalid
# - return error

# %%
name = "shafique ur rehman"
print(f"name is {name} and data type is {type(name)}")
# Out:
# name is shafique ur rehman and data type is <class 'str'>

# %%
#invalid string to integer - return error

#name_2 = int(name)
#print(name_2)
